# %%
! ./run_train.sh
# Out:
# Namespace(batch_size=32, debug=True, epochs=5000, latent_size=64, log_interval=1, lr=0.001, name='default', resume=False, root='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/modelnet40_off_aligned', sample_num=2048, seed=42, weight_file='')
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:0  loss: 6021.021484 , chamfer: 1.866036, l2: 6841.815430
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:1  loss: 5977.986816 , chamfer: 1.999419, l2: 6792.894531
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:2  loss: 5855.304688 , chamfer: 1.963324, l2: 6653.487305
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:3  loss: 5799.900879 , chamfer: 1.938742, l2: 6590.532227
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# ...

# %%
# %run rotate.py
# Out:
# Namespace(batch_size=32, debug=True, epochs=5000, latent_size=64, log_interval=1, lr=0.001, name='default', resume=False, root='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/modelnet40_off_aligned', sample_num=2048, seed=42, weight_file='')
# /home/mmvc/mmvc-ny-nas/Yi_Shi/data/gen/random_sample_gt_rate_2048/train
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:0  loss: 5901.595703 , chamfer: 1.819654, l2: 6706.110840
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:1  loss: 5869.329590 , chamfer: 1.995614, l2: 6669.420898
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:2  loss: 5758.290527 , chamfer: 1.940886, l2: 6543.247559
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:3  loss: 5660.541992 , chamfer: 1.976754, l2: 6432.164551
# ...
