# %%
# !python eval.py
# Out:
# Namespace(batch_size=32, debug=True, epochs=5000, latent_size=64, log_interval=1, lr=0.001, name='default', resume=True, root='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/modelnet40_off_aligned', sample_num=2048, seed=42, weight_file='')
# cuda
# /home/mmvc/mmvc-ny-nas/Yi_Shi/data/gen/random_sample_gt_rate_2048/train
# loading checkpoint!
# 0
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# 348.1694030761719 3.6998448371887207
# 1
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# 427.8948059082031 4.022188663482666
# 2
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# 317.3658447265625 3.5574095249176025
# 3
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# 360.0870666503906 3.736823797225952
# 4
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# 363.1839294433594 3.6946585178375244
# 5
# ...
