# %%
! ./run_train.sh
# Out:
# Namespace(batch_size=32, debug=True, epochs=5000, latent_size=64, log_interval=1, lr=0.01, name='default', resume=False, root='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/modelnet40_off_aligned', sample_num=2048, seed=42, weight_file='')
# /home/mmvc/mmvc-ny-nas/Yi_Shi/data/gen/random_sample_gt_rate_2048/train
# 6012
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:0  loss: 6020.959473 , chamfer: 1.870323, l2: 6841.744141
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:1  loss: 5889.282715 , chamfer: 1.960561, l2: 6692.099121
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:2  loss: 5543.204590 , chamfer: 2.188348, l2: 6298.797852
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:3  loss: 5326.016113 , chamfer: 2.180794, l2: 6051.993652
# ...

# %%
# %run rotate.py
# Out:
# Namespace(batch_size=32, debug=True, epochs=5000, latent_size=64, log_interval=1, lr=0.001, name='default', resume=False, root='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/modelnet40_off_aligned', sample_num=2048, seed=42, weight_file='')
# /home/mmvc/mmvc-ny-nas/Yi_Shi/data/gen/random_sample_gt_rate_2048/train
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:0  loss: 6036.962402 , chamfer: 1.875967, l2: 6859.928711
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:1  loss: 5982.916016 , chamfer: 2.056490, l2: 6798.488281
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:2  loss: 5862.525391 , chamfer: 1.995854, l2: 6661.688477
# torch.Size([32, 3, 2048]) torch.Size([32, 3, 2048]) torch.Size([32, 64, 2048])
# Epoch:[0|5000], Batch:3  loss: 5765.596191 , chamfer: 2.066752, l2: 6551.532227
# ...
